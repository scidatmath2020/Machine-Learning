# %% [markdown]
# <img src="logo.png">

# %% [markdown]
# # DBScan
#
# <img src="ml40.png">
# <img src="ml41.png">
# <img src="ml42.png">
#
# ## El agoritmo
#
# <img src="ml43.png">
#
# ## Ventajas y desventajas
#
# <img src="ml44.png">
