# %% [markdown]
# <img src="logo.png">

# %% [markdown]
# # Métodos Ensamblados
#
# Recordemos la estructura básica de nuestros algoritmos:
#
# <img src="ml82.png">
# <img src="ml83.png">
# <img src="ml84.png">

# %% [markdown]
# ## Métodos de ensamblado
#
# <img src="ml85.png">

# %% [markdown]
# ### Bagging
#
# <img src="ml86.png">

# %% [markdown]
# ### Boosting
#
# <img src="ml87.png">

# %% [markdown]
# ### Bosques aleatorios
#
# <img src="ml88.png">

# %% [markdown]
# ### XGboost
#
# <img src="ml89.png">

# %% [markdown]
# ### Stacking
#
# <img src="ml90.png">
