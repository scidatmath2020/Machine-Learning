# %% [markdown]
# <img src="logo.png">

# %% [markdown]
# # Análisis por componentes principales
#
# <img src="ml45.png">
# <img src="ml46.png">
# <img src="ml47.png">
# <img src="ml48.png">
# <img src="ml49.png">
# <img src="ml50.png">

# %% [markdown]
# # El método
#
# <img src="ml51.png">
# <img src="ml52.png">
